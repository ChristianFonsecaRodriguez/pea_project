# %%
import pandas as pd
import numpy as np

# %%
from pycaret.regression import *

# %%
import mlflow

# %%
# mlflow.set_tracking_uri('http://127.0.0.1:5000')

# %%
mlflow.set_tracking_uri('http://ec2-54-165-160-184.compute-1.amazonaws.com:5000')

# %%
# No incluir columnas
exclude = ['Posted On', 'Area Locality','Floor']

# %%
data = pd.read_csv('raw.csv')

# %%
data
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# 3                  Dumdum Park    Kolkata       Unfurnished  Bachelors/Family
# 4                South Dum Dum    Kolkata       Unfurnished         Bachelors
# ...                        ...        ...               ...               ...
# 4741              Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742      Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743      Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744                Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745           Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 0            2    Contact Owner
# 1            1    Contact Owner
# 2            1    Contact Owner
# 3            1    Contact Owner
# 4            1    Contact Owner
# ...        ...              ...
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# 4744         2    Contact Agent
# 4745         2    Contact Owner
#
# [4746 rows x 12 columns]

# %%
s = setup(data, target='Rent', session_id=123, ignore_features=exclude,
          experiment_name='model_rent_lgbm', log_experiment=True)
# Out:
# <style type="text/css">
# #T_f43b9_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f43b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f43b9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f43b9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f43b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f43b9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f43b9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f43b9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f43b9_row1_col1" class="data row1 col1" >Rent</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f43b9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f43b9_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f43b9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f43b9_row3_col1" class="data row3 col1" >(4746, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f43b9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f43b9_row4_col1" class="data row4 col1" >(4746, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f43b9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f43b9_row5_col1" class="data row5 col1" >(3322, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f43b9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f43b9_row6_col1" class="data row6 col1" >(1424, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f43b9_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_f43b9_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f43b9_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_f43b9_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f43b9_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_f43b9_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f43b9_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_f43b9_row10_col1" class="data row10 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f43b9_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_f43b9_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f43b9_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_f43b9_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f43b9_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_f43b9_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f43b9_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_f43b9_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f43b9_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_f43b9_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f43b9_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_f43b9_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f43b9_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_f43b9_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f43b9_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_f43b9_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f43b9_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_f43b9_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f43b9_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_f43b9_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f43b9_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_f43b9_row21_col1" class="data row21 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f43b9_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_f43b9_row22_col1" class="data row22 col1" >model_rent_lgbm</td>
#     </tr>
#     <tr>
#       <th id="T_f43b9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f43b9_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_f43b9_row23_col1" class="data row23 col1" >9564</td>
#     </tr>
#   </tbody>
# </table>
# 2023/11/02 20:19:37 INFO mlflow.tracking.fluent: Experiment with name 'model_rent_lgbm' does not exist. Creating a new experiment.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s = setup(data, target='Rent', session_id=123, ignore_features=exclude,
#       2           experiment_name='model_rent_lgbm', log_experiment=True)
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\pycaret\regression\functional.py:593, in setup(data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, verbose, memory, profile, profile_kwargs)
#     591 exp = _EXPERIMENT_CLASS()
#     592 set_current_experiment(exp)
# --> 593 return exp.setup(
#     594     data=data,
#     595     data_func=data_func,
#     596     target=target,
#     597     index=index,
#     598     train_size=train_size,
#     599     test_data=test_data,
#     600     ordinal_features=ordinal_features,
#     601     numeric_features=numeric_features,
#     602     categorical_features=categorical_features,
#     603     date_features=date_features,
#     604     text_features=text_features,
#     605     ignore_features=ignore_features,
#     606     keep_features=keep_features,
#     607     preprocess=preprocess,
#     608     create_date_columns=create_date_columns,
#     609     imputation_type=imputation_type,
#     610     numeric_imputation=numeric_imputation,
#     611     categorical_imputation=categorical_imputation,
#     612     iterative_imputation_iters=iterative_imputation_iters,
#     613     numeric_iterative_imputer=numeric_iterative_imputer,
#     614     categorical_iterative_imputer=categorical_iterative_imputer,
#     615     text_features_method=text_features_method,
#     616     max_encoding_ohe=max_encoding_ohe,
#     617     encoding_method=encoding_method,
#     618     rare_to_value=rare_to_value,
#     619     rare_value=rare_value,
#     620     polynomial_features=polynomial_features,
#     621     polynomial_degree=polynomial_degree,
#     622     low_variance_threshold=low_variance_threshold,
#     623     group_features=group_features,
#     624     drop_groups=drop_groups,
#     625     remove_multicollinearity=remove_multicollinearity,
#     626     multicollinearity_threshold=multicollinearity_threshold,
#     627     bin_numeric_features=bin_numeric_features,
#     628     remove_outliers=remove_outliers,
#     629     outliers_method=outliers_method,
#     630     outliers_threshold=outliers_threshold,
#     631     transformation=transformation,
#     632     transformation_method=transformation_method,
#     633     normalize=normalize,
#     634     normalize_method=normalize_method,
#     635     pca=pca,
#     636     pca_method=pca_method,
#     637     pca_components=pca_components,
#     638     feature_selection=feature_selection,
#     639     feature_selection_method=feature_selection_method,
#     640     feature_selection_estimator=feature_selection_estimator,
#     641     n_features_to_select=n_features_to_select,
#     642     transform_target=transform_target,
#     643     transform_target_method=transform_target_method,
#     644     custom_pipeline=custom_pipeline,
#     645     custom_pipeline_position=custom_pipeline_position,
#     646     data_split_shuffle=data_split_shuffle,
#     647     data_split_stratify=data_split_stratify,
#     648     fold_strategy=fold_strategy,
#     649     fold=fold,
#     650     fold_shuffle=fold_shuffle,
#     651     fold_groups=fold_groups,
#     652     n_jobs=n_jobs,
#     653     use_gpu=use_gpu,
#     654     html=html,
#     655     session_id=session_id,
#     656     system_log=system_log,
#     657     log_experiment=log_experiment,
#     658     experiment_name=experiment_name,
#     659     experiment_custom_tags=experiment_custom_tags,
#     660     log_plots=log_plots,
#     661     log_profile=log_profile,
#     662     log_data=log_data,
#     663     verbose=verbose,
#     664     memory=memory,
#     665     profile=profile,
#     666     profile_kwargs=profile_kwargs,
#     667 )
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\pycaret\regression\oop.py:970, in RegressionExperiment.setup(self, data, data_func, target, index, train_size, test_data, ordinal_features, numeric_features, categorical_features, date_features, text_features, ignore_features, keep_features, preprocess, create_date_columns, imputation_type, numeric_imputation, categorical_imputation, iterative_imputation_iters, numeric_iterative_imputer, categorical_iterative_imputer, text_features_method, max_encoding_ohe, encoding_method, rare_to_value, rare_value, polynomial_features, polynomial_degree, low_variance_threshold, group_features, drop_groups, remove_multicollinearity, multicollinearity_threshold, bin_numeric_features, remove_outliers, outliers_method, outliers_threshold, transformation, transformation_method, normalize, normalize_method, pca, pca_method, pca_components, feature_selection, feature_selection_method, feature_selection_estimator, n_features_to_select, transform_target, transform_target_method, custom_pipeline, custom_pipeline_position, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, html, session_id, system_log, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, engine, verbose, memory, profile, profile_kwargs)
#     967 self._all_metrics = self._get_metrics()
#     969 runtime = np.array(time.time() - runtime_start).round(2)
# --> 970 self._set_up_logging(
#     971     runtime,
#     972     log_data,
#     973     log_profile,
#     974     experiment_custom_tags=experiment_custom_tags,
#     975 )
#     977 self._setup_ran = True
#     978 self.logger.info(f"setup() successfully completed in {runtime}s...............")
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:268, in _SupervisedExperiment._set_up_logging(self, runtime, log_data, log_profile, experiment_custom_tags)
#     263         raise TypeError(
#     264             "experiment_custom_tags parameter must be dict if not None"
#     265         )
#     267 if self.logging_param:
# --> 268     self.logging_param.log_experiment(
#     269         self,
#     270         log_profile,
#     271         log_data,
#     272         experiment_custom_tags,
#     273         runtime,
#     274     )
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\pycaret\loggers\dashboard_logger.py:229, in DashboardLogger.log_experiment(self, experiment, log_profile, log_data, experiment_custom_tags, runtime)
#     221 experiment.save_model(
#     222     experiment.pipeline,
#     223     os.path.join(tmpdir, "Transformation Pipeline"),
#     224     verbose=False,
#     225 )
#     226 console.info(
#     227     "SubProcess save_model() end =================================="
#     228 )
# --> 229 [
#     230     logger.log_artifact(
#     231         os.path.join(tmpdir, "Transformation Pipeline.pkl"),
#     232         "transformation_pipe",
#     233     )
#     234     for logger in self.loggers
#     235 ]
#     237 # Log pandas profile
#     238 if log_profile:
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\pycaret\loggers\dashboard_logger.py:230, in <listcomp>(.0)
#     221 experiment.save_model(
#     222     experiment.pipeline,
#     223     os.path.join(tmpdir, "Transformation Pipeline"),
#     224     verbose=False,
#     225 )
#     226 console.info(
#     227     "SubProcess save_model() end =================================="
#     228 )
#     229 [
# --> 230     logger.log_artifact(
#     231         os.path.join(tmpdir, "Transformation Pipeline.pkl"),
#     232         "transformation_pipe",
#     233     )
#     234     for logger in self.loggers
#     235 ]
#     237 # Log pandas profile
#     238 if log_profile:
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\pycaret\loggers\mlflow_logger.py:125, in MlflowLogger.log_artifact(self, file, type)
#     123 def log_artifact(self, file, type="artifact"):
#     124     with set_active_mlflow_run(self.active_run):
# --> 125         mlflow.log_artifact(file)
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\tracking\fluent.py:974, in log_artifact(local_path, artifact_path)
#     951 """
#     952 Log a local file or directory as an artifact of the currently active run. If no run is
#     953 active, this method will create a new active run.
#    (...)
#     971         mlflow.log_artifact("features.txt")
#     972 """
#     973 run_id = _get_or_start_run().info.run_id
# --> 974 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\tracking\client.py:1142, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1107 def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#    1108     """
#    1109     Write a local file or directory to the remote ``artifact_uri``.
#    1110
#    (...)
#    1140         is_dir: False
#    1141     """
# -> 1142     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\tracking\_tracking_service\client.py:529, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     527     artifact_repo.log_artifacts(local_path, path_name)
#     528 else:
# --> 529     artifact_repo.log_artifact(local_path, artifact_path)
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\store\artifact\s3_artifact_repo.py:166, in S3ArtifactRepository.log_artifact(self, local_file, artifact_path)
#     163     dest_path = posixpath.join(dest_path, artifact_path)
#     164 dest_path = posixpath.join(dest_path, os.path.basename(local_file))
#     165 self._upload_file(
# --> 166     s3_client=self._get_s3_client(), local_file=local_file, bucket=bucket, key=dest_path
#     167 )
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\store\artifact\s3_artifact_repo.py:124, in S3ArtifactRepository._get_s3_client(self)
#     123 def _get_s3_client(self):
# --> 124     return _get_s3_client(
#     125         access_key_id=self._access_key_id,
#     126         secret_access_key=self._secret_access_key,
#     127         session_token=self._session_token,
#     128     )
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\store\artifact\s3_artifact_repo.py:99, in _get_s3_client(addressing_style, access_key_id, secret_access_key, session_token, region_name, s3_endpoint_url)
#      96 # Invalidate cache every `_MAX_CACHE_SECONDS`
#      97 timestamp = int(_get_utcnow_timestamp() / _MAX_CACHE_SECONDS)
# ---> 99 return _cached_get_s3_client(
#     100     signature_version,
#     101     addressing_style,
#     102     s3_endpoint_url,
#     103     verify,
#     104     timestamp,
#     105     access_key_id=access_key_id,
#     106     secret_access_key=secret_access_key,
#     107     session_token=session_token,
#     108     region_name=region_name,
#     109 )
#
# File d:\trabajo\dmc\202311\pea da\pea_da\lib\site-packages\mlflow\store\artifact\s3_artifact_repo.py:51, in _cached_get_s3_client(signature_version, addressing_style, s3_endpoint_url, verify, timestamp, access_key_id, secret_access_key, session_token, region_name)
#      26 @lru_cache(maxsize=64)
#      27 def _cached_get_s3_client(
#      28     signature_version,
#    (...)
#      36     region_name=None,
#      37 ):  # pylint: disable=unused-argument
#      38     """Returns a boto3 client, caching to avoid extra boto3 verify calls.
#      39
#      40     This method is outside of the S3ArtifactRepository as it is
#    (...)
#      49     we utilise the `timestamp` parameter to invalidate cache.
#      50     """
# ---> 51     import boto3
#      52     from botocore.client import Config
#      54     # Making it possible to access public S3 buckets
#      55     # Workaround for https://github.com/boto/botocore/issues/2442
#
# ModuleNotFoundError: No module named 'boto3'

# %%
# best = compare_models()

# %%
best = create_model('lightgbm')

# %%
tuned_model = tune_model(best, n_iter=20)
# Out:
# <style type="text/css">
# #T_4fba4_row10_col0, #T_4fba4_row10_col1, #T_4fba4_row10_col2, #T_4fba4_row10_col3, #T_4fba4_row10_col4, #T_4fba4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4fba4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fba4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4fba4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4fba4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4fba4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4fba4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4fba4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fba4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4fba4_row0_col0" class="data row0 col0" >17151.1262</td>
#       <td id="T_4fba4_row0_col1" class="data row0 col1" >3544750890.3677</td>
#       <td id="T_4fba4_row0_col2" class="data row0 col2" >59537.8106</td>
#       <td id="T_4fba4_row0_col3" class="data row0 col3" >0.5023</td>
#       <td id="T_4fba4_row0_col4" class="data row0 col4" >0.5576</td>
#       <td id="T_4fba4_row0_col5" class="data row0 col5" >0.4380</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4fba4_row1_col0" class="data row1 col0" >23019.7573</td>
#       <td id="T_4fba4_row1_col1" class="data row1 col1" >35356443031.6662</td>
#       <td id="T_4fba4_row1_col2" class="data row1 col2" >188033.0903</td>
#       <td id="T_4fba4_row1_col3" class="data row1 col3" >0.0904</td>
#       <td id="T_4fba4_row1_col4" class="data row1 col4" >0.5258</td>
#       <td id="T_4fba4_row1_col5" class="data row1 col5" >0.4432</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4fba4_row2_col0" class="data row2 col0" >9964.6935</td>
#       <td id="T_4fba4_row2_col1" class="data row2 col1" >443483401.5312</td>
#       <td id="T_4fba4_row2_col2" class="data row2 col2" >21059.0456</td>
#       <td id="T_4fba4_row2_col3" class="data row2 col3" >0.7809</td>
#       <td id="T_4fba4_row2_col4" class="data row2 col4" >0.3861</td>
#       <td id="T_4fba4_row2_col5" class="data row2 col5" >0.3239</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4fba4_row3_col0" class="data row3 col0" >12811.9146</td>
#       <td id="T_4fba4_row3_col1" class="data row3 col1" >941325046.6878</td>
#       <td id="T_4fba4_row3_col2" class="data row3 col2" >30681.0210</td>
#       <td id="T_4fba4_row3_col3" class="data row3 col3" >0.6523</td>
#       <td id="T_4fba4_row3_col4" class="data row3 col4" >0.4457</td>
#       <td id="T_4fba4_row3_col5" class="data row3 col5" >0.3868</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4fba4_row4_col0" class="data row4 col0" >11880.4413</td>
#       <td id="T_4fba4_row4_col1" class="data row4 col1" >867085076.8055</td>
#       <td id="T_4fba4_row4_col2" class="data row4 col2" >29446.3084</td>
#       <td id="T_4fba4_row4_col3" class="data row4 col3" >0.7577</td>
#       <td id="T_4fba4_row4_col4" class="data row4 col4" >0.4618</td>
#       <td id="T_4fba4_row4_col5" class="data row4 col5" >0.4016</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4fba4_row5_col0" class="data row5 col0" >14968.1714</td>
#       <td id="T_4fba4_row5_col1" class="data row5 col1" >1318724860.2891</td>
#       <td id="T_4fba4_row5_col2" class="data row5 col2" >36314.2515</td>
#       <td id="T_4fba4_row5_col3" class="data row5 col3" >0.7173</td>
#       <td id="T_4fba4_row5_col4" class="data row5 col4" >0.4525</td>
#       <td id="T_4fba4_row5_col5" class="data row5 col5" >0.3823</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4fba4_row6_col0" class="data row6 col0" >13206.3934</td>
#       <td id="T_4fba4_row6_col1" class="data row6 col1" >1244761618.9319</td>
#       <td id="T_4fba4_row6_col2" class="data row6 col2" >35281.1794</td>
#       <td id="T_4fba4_row6_col3" class="data row6 col3" >0.5680</td>
#       <td id="T_4fba4_row6_col4" class="data row6 col4" >0.4703</td>
#       <td id="T_4fba4_row6_col5" class="data row6 col5" >0.4093</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4fba4_row7_col0" class="data row7 col0" >10470.8634</td>
#       <td id="T_4fba4_row7_col1" class="data row7 col1" >502313590.6077</td>
#       <td id="T_4fba4_row7_col2" class="data row7 col2" >22412.3535</td>
#       <td id="T_4fba4_row7_col3" class="data row7 col3" >0.7494</td>
#       <td id="T_4fba4_row7_col4" class="data row7 col4" >0.4297</td>
#       <td id="T_4fba4_row7_col5" class="data row7 col5" >0.3696</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4fba4_row8_col0" class="data row8 col0" >11754.2375</td>
#       <td id="T_4fba4_row8_col1" class="data row8 col1" >1532237411.1117</td>
#       <td id="T_4fba4_row8_col2" class="data row8 col2" >39143.8042</td>
#       <td id="T_4fba4_row8_col3" class="data row8 col3" >0.5702</td>
#       <td id="T_4fba4_row8_col4" class="data row8 col4" >0.4549</td>
#       <td id="T_4fba4_row8_col5" class="data row8 col5" >0.3496</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4fba4_row9_col0" class="data row9 col0" >11642.5253</td>
#       <td id="T_4fba4_row9_col1" class="data row9 col1" >1269258959.2176</td>
#       <td id="T_4fba4_row9_col2" class="data row9 col2" >35626.6608</td>
#       <td id="T_4fba4_row9_col3" class="data row9 col3" >0.6613</td>
#       <td id="T_4fba4_row9_col4" class="data row9 col4" >0.4730</td>
#       <td id="T_4fba4_row9_col5" class="data row9 col5" >0.3940</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4fba4_row10_col0" class="data row10 col0" >13687.0124</td>
#       <td id="T_4fba4_row10_col1" class="data row10 col1" >4702038388.7216</td>
#       <td id="T_4fba4_row10_col2" class="data row10 col2" >49753.5525</td>
#       <td id="T_4fba4_row10_col3" class="data row10 col3" >0.6050</td>
#       <td id="T_4fba4_row10_col4" class="data row10 col4" >0.4657</td>
#       <td id="T_4fba4_row10_col5" class="data row10 col5" >0.3898</td>
#     </tr>
#     <tr>
#       <th id="T_4fba4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4fba4_row11_col0" class="data row11 col0" >3702.9298</td>
#       <td id="T_4fba4_row11_col1" class="data row11 col1" >10251272286.9674</td>
#       <td id="T_4fba4_row11_col2" class="data row11 col2" >47187.0999</td>
#       <td id="T_4fba4_row11_col3" class="data row11 col3" >0.1926</td>
#       <td id="T_4fba4_row11_col4" class="data row11 col4" >0.0452</td>
#       <td id="T_4fba4_row11_col5" class="data row11 col5" >0.0348</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [LightGBM] [Warning] feature_fraction is set=1.0, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1.0
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2

# %%
final = finalize_model(tuned_model)

# %%
final
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['BHK', 'Size', 'Bathroom'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['Area Type', 'City',
#                                              'Furnishing Status',
#                                              'Tenant Preferred',
#                                              'Point of Contact'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('ordinal_encoding',
#                  Tra...
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator',
#                  LGBMRegressor(bagging_fraction=0.6, bagging_freq=2,
#                                feature_fraction=1.0, learning_rate=0.15,
#                                min_child_samples=61, min_split_gain=0.8,
#                                n_estimators=90, n_jobs=-1, num_leaves=70,
#                                random_state=123, reg_alpha=0.0001,
#                                reg_lambda=0.05))])

# %%
save_model(final,'model_lgb')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['BHK', 'Size', 'Bathroom'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Area Type', 'City',
#                                               'Furnishing Status',
#                                               'Tenant Preferred',
#                                               'Point of Contact'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   Tra...
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
#                   LGBMRegressor(bagging_fraction=0.6, bagging_freq=2,
#                                 feature_fraction=1.0, learning_rate=0.15,
#                                 min_child_samples=61, min_split_gain=0.8,
#                                 n_estimators=90, n_jobs=-1, num_leaves=70,
#                                 random_state=123, reg_alpha=0.0001,
#                                 reg_lambda=0.05))]),
#  'model_lgb.pkl')
